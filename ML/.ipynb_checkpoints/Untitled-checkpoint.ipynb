# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Athletes.csv')
df.sample(5)
# Out:
#          Bib    Zip  Age Age Group Gender  First Half  Second Half  Finish  \
# 10303  19410  29708   47     45-49      F        6594         7680   14274
# 8035   18646  98022   55     55-59      F        6307         6965   13272
# 9960   21243  95008   65     65-69      M        6480         7617   14097
# 13849  23148  49331   60     60-64      F        7443         9333   16776
# 16220  27018  78209   56     55-59      F        9080        10625   19705
#
#        Positive Split  Percent Change
# 10303            1086        0.164695
# 8035              658        0.104329
# 9960             1137        0.175463
# 13849            1890        0.253930
# 16220            1545        0.170154

# %%
df.shape
# Out:
# (17220, 10)

# %%
df.isnull().sum()
# Out:
# Bib               0
# Zip               0
# Age               0
# Age Group         0
# Gender            0
# First Half        0
# Second Half       0
# Finish            0
# Positive Split    0
# Percent Change    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - The dataset doesn't contain any duplicate values or null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17220 entries, 0 to 17219
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bib             17220 non-null  int64
#  1   Zip             17220 non-null  int64
#  2   Age             17220 non-null  int64
#  3   Age Group       17220 non-null  object
#  4   Gender          17220 non-null  object
#  5   First Half      17220 non-null  int64
#  6   Second Half     17220 non-null  int64
#  7   Finish          17220 non-null  int64
#  8   Positive Split  17220 non-null  int64
#  9   Percent Change  17220 non-null  float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# - We can drop the age group column since it doesn't have any use

# %%
df.drop(columns=['Age Group'],inplace=True)

# %% [markdown]
# - We have categorical data so we convert them using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# %%
df.head(1)
# Out:
#    Bib    Zip  Age  Gender  First Half  Second Half  Finish  Positive Split  \
# 0   25  93730   30       1        3832         3961    7793             129
#
#    Percent Change
# 0        0.033664

# %% [markdown]
# ### Finding correlation between the feature helps to predict the age of an athelete

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                      Bib       Zip       Age    Gender  First Half  \
# Bib             1.000000 -0.260689  0.205467 -0.342244    0.811329
# Zip            -0.260689  1.000000  0.139000  0.015515   -0.225849
# Age             0.205467  0.139000  1.000000  0.126719    0.237932
# Gender         -0.342244  0.015515  0.126719  1.000000   -0.294834
# First Half      0.811329 -0.225849  0.237932 -0.294834    1.000000
# Second Half     0.720919 -0.213430  0.234699 -0.167899    0.881389
# Finish          0.781434 -0.225190  0.243159 -0.227421    0.958840
# Positive Split  0.282885 -0.104180  0.129406  0.084897    0.334352
# Percent Change  0.104125 -0.054281  0.070819  0.150295    0.114495
#
#                 Second Half    Finish  Positive Split  Percent Change
# Bib                0.720919  0.781434        0.282885        0.104125
# Zip               -0.213430 -0.225190       -0.104180       -0.054281
# Age                0.234699  0.243159        0.129406        0.070819
# Gender            -0.167899 -0.227421        0.084897        0.150295
# First Half         0.881389  0.958840        0.334352        0.114495
# Second Half        1.000000  0.979245        0.739898        0.563033
# Finish             0.979245  1.000000        0.588195        0.387554
# Positive Split     0.739898  0.588195        1.000000        0.960237
# Percent Change     0.563033  0.387554        0.960237        1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_with_age=correlation_matrix['Age']

# %%
correlation_with_age=correlation_with_age.to_dict()

# %%
correlation_df = pd.DataFrame(list(correlation_with_age.items()), columns=['Feature', 'Correlation with Age'])

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=correlation_df, x='Correlation with Age', y='Feature', palette='viridis')
plt.title('Correlation of Features with Age')
plt.show()
# Out:
# C:\Users\upend\AppData\Local\Temp\ipykernel_15316\899288297.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=correlation_df, x='Correlation with Age', y='Feature', palette='viridis')

# %%
sns.set(style="whitegrid")

# Creating scatter plots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 15))

# Plotting Age vs Bib
sns.scatterplot(ax=axes[0, 0], data=df, x='Age', y='Bib')
axes[0, 0].set_title('Age vs Bib')

# Plotting Age vs Zip
sns.scatterplot(ax=axes[0, 1], data=df, x='Age', y='Zip')
axes[0, 1].set_title('Age vs Zip')

# Plotting Age vs Gender
sns.scatterplot(ax=axes[0, 2], data=df, x='Age', y='Gender')
axes[0, 2].set_title('Age vs Gender')

# Plotting Age vs First Half
sns.scatterplot(ax=axes[1, 0], data=df, x='Age', y='First Half')
axes[1, 0].set_title('Age vs First Half')

# Plotting Age vs Second Half
sns.scatterplot(ax=axes[1, 1], data=df, x='Age', y='Second Half')
axes[1, 1].set_title('Age vs Second Half')

# Plotting Age vs Finish
sns.scatterplot(ax=axes[1, 2], data=df, x='Age', y='Finish')
axes[1, 2].set_title('Age vs Finish')

# Plotting Age vs Positive Split
sns.scatterplot(ax=axes[2, 0], data=df, x='Age', y='Positive Split')
axes[2, 0].set_title('Age vs Positive Split')

# Plotting Age vs Percent Change
sns.scatterplot(ax=axes[2, 1], data=df, x='Age', y='Percent Change')
axes[2, 1].set_title('Age vs Percent Change')

# Removing the last empty subplot
fig.delaxes(axes[2, 2])

plt.tight_layout()
plt.show()

# %%
df.head(1)
# Out:
#    Bib    Zip  Age  Gender  First Half  Second Half  Finish  Positive Split  \
# 0   25  93730   30       1        3832         3961    7793             129
#
#    Percent Change
# 0        0.033664

# %%
X=df.drop(columns='Age')
y=df['Age']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y , random_state=104,  test_size=0.25,  shuffle=True)

# %%
X_test
# Out:
#          Bib    Zip  Gender  First Half  Second Half  Finish  Positive Split  \
# 3025    5687  10034       1        5503         5860   11363             357
# 16679  25985  22902       0       10171        10427   20598             256
# 12482  20784  75230       1        7126         8513   15639            1387
# 3579   13736   8012       0        5256         6378   11634            1122
# 16694  26407   2356       1        9107        11544   20651            2437
# ...      ...    ...     ...         ...          ...     ...             ...
# 2609    9311  30092       0        5054         6104   11158            1050
# 6068   10709  98102       0        5840         6693   12533             853
# 8977   18981  94609       0        6601         7054   13655             453
# 6483    5057  93704       1        6262         6421   12683             159
# 11572  19399  74105       0        6740         8260   15000            1520
#
#        Percent Change
# 3025         0.064874
# 16679        0.025170
# 12482        0.194639
# 3579         0.213470
# 16694        0.267596
# ...               ...
# 2609         0.207756
# 6068         0.146062
# 8977         0.068626
# 6483         0.025391
# 11572        0.225519
#
# [4305 rows x 8 columns]
